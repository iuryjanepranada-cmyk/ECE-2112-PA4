# %% [markdown]
# # **EXPERIMENT #4 - DATA WRANGLING AND DAT VISUALIZATION**

# %%
import pandas as pd

# %% [markdown]
# ## **A. VISAYAS COMMUNICATION DATAFRAME**

# %%
df = pd.read_excel('/content/board2.xlsx')
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
df.describe()
# Out:
#             Math  Electronics       GEAS  Communication
# count  30.000000     30.00000  30.000000      30.000000
# mean   72.166667     61.60000  71.866667      61.966667
# std    12.660237     17.29381  15.725519      15.376837
# min    48.000000     35.00000  40.000000      41.000000
# 25%    64.250000     47.00000  61.250000      49.000000
# 50%    73.500000     60.00000  76.000000      60.000000
# 75%    83.000000     76.50000  83.750000      72.750000
# max    89.000000     91.00000  94.000000      88.000000

# %%
Average = df['Average'] = df[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)
Average
# Out:
# 0     75.00
# 1     67.25
# 2     72.75
# 3     70.50
# 4     69.00
# 5     75.50
# 6     58.50
# 7     61.75
# 8     47.75
# 9     67.25
# 10    54.75
# 11    76.00
# 12    62.25
# 13    80.50
# 14    59.00
# 15    77.25
# 16    70.50
# 17    63.50
# 18    73.00
# 19    66.50
# 20    68.50
# 21    62.50
# 22    68.75
# 23    57.75
# 24    75.25
# 25    65.75
# 26    60.75
# 27    67.75
# 28    63.50
# 29    68.00
# dtype: float64

# %%
df = df.assign(Average=Average)
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
VisComm = df.loc[(df ['Hometown'] == 'Visayas') & (df ['Track'] == 'Communication'), ['Name', 'Gender', 'Math', 'Electronics', 'Average']]
VisComm
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75

# %%
VisComm.shape[0]
# Out:
# 5

# %% [markdown]
# ## **B. VISAYAS FEMALE DATAFRAME**

# %%
VisFemale = df.loc[(df ['Hometown'] == 'Visayas') & (df ['Gender'] == 'Female'), ['Name', 'Track', 'GEAS', 'Electronics', 'Average']]
VisFemale
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75

# %%
VisFemale[VisFemale['Average'] >= 60]
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 25  S26   Instrumentation    83           47    65.75

# %% [markdown]
# ## **C. CATEGORY-AVERAGE VISUALIZATION**

# %% [markdown]
# ***A. For each feature, compute the mean of Average for every category using Pandas***

# %% [markdown]
# **A.1  Track**

# %%
Communication_mean = df.loc[df['Track']=='Communication', 'Average'].mean()
Instrumentation_mean = df.loc[df['Track']=='Instrumentation', 'Average'].mean()
Microelectronics_mean = df.loc[df['Track']=='Microelectronics', 'Average'].mean()

# %%
Communication_mean
# Out:
# np.float64(67.975)

# %%
Instrumentation_mean
# Out:
# np.float64(65.225)

# %%
Microelectronics_mean
# Out:
# np.float64(67.5)

# %% [markdown]
# **A.2 Gender**

# %%
Female_mean = df.loc[df['Gender']=='Female', 'Average'].mean()
Male_mean = df.loc[df['Gender']=='Male', 'Average'].mean()

# %%
Female_mean
# Out:
# np.float64(66.61666666666666)

# %%
Male_mean
# Out:
# np.float64(67.18333333333334)

# %% [markdown]
# **A.3 Hometown**

# %%
Luzon_mean = df.loc[df['Hometown']=='Luzon', 'Average'].mean()
Visayas_mean = df.loc[df['Hometown']=='Visayas', 'Average'].mean()
Mindanao_mean = df.loc[df['Hometown']=='Mindanao', 'Average'].mean()

# %%
Luzon_mean
# Out:
# np.float64(68.08333333333333)

# %%
Visayas_mean
# Out:
# np.float64(65.75)

# %%
Mindanao_mean
# Out:
# np.float64(66.67857142857143)

# %% [markdown]
# ***B. Display the three summary tables.***

# %%
Track_table = pd.DataFrame({
    'Track': ['Communication', 'Instrumentation', 'Microelectronics'],
    'Average': [Communication_mean, Instrumentation_mean, Microelectronics_mean]
})
Track_table
# Out:
#               Track  Average
# 0     Communication   67.975
# 1   Instrumentation   65.225
# 2  Microelectronics   67.500

# %%
Gender_table = pd.DataFrame({
    'Gender': ['Female', 'Male'],
    'Average': [Female_mean, Male_mean]
})
Gender_table
# Out:
#    Gender    Average
# 0  Female  66.616667
# 1    Male  67.183333

# %%
Hometown_table = pd.DataFrame({
    'Hometown': ['Luzon', 'Visayas', 'Mindanao'],
    'Average': [Luzon_mean, Visayas_mean, Mindanao_mean]
})
Hometown_table
# Out:
#    Hometown    Average
# 0     Luzon  68.083333
# 1   Visayas  65.750000
# 2  Mindanao  66.678571

# %% [markdown]
# **C. Create one figure containing three bar charts: mean Average by Track, by Gender, and by Hometown**

# %%
import matplotlib.pyplot as plt

Track_table = pd.DataFrame({
    'Track': ['Communication', 'Instrumentation', 'Microelectronics'],
    'Average': [Communication_mean, Instrumentation_mean, Microelectronics_mean]
})
Gender_table = pd.DataFrame({
    'Gender': ['Female', 'Male'],
    'Average': [Female_mean, Male_mean]
})
Hometown_table = pd.DataFrame({
    'Hometown': ['Luzon', 'Visayas', 'Mindanao'],
    'Average': [Luzon_mean, Visayas_mean, Mindanao_mean]
})

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

Track_table.plot(kind='bar', x='Track', y='Average', ax=axes[0], legend=False)
axes[0].set_title('Track Mean Average')
axes[0].set_xlabel('Track')
axes[0].set_ylabel('Mean Average')
axes[0].tick_params(axis='x', rotation=45)

Gender_table.plot(kind='bar', x='Gender', y='Average', ax=axes[1], legend=False)
axes[1].set_title('Gender Mean Average')
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('Mean Average')
axes[1].tick_params(axis='x', rotation=0)

Hometown_table.plot(kind='bar', x='Hometown', y='Average', ax=axes[2], legend=False)
axes[2].set_title('Hometown Mean Average')
axes[2].set_xlabel('Hometown')
axes[2].set_ylabel('Mean Average')
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **D. Below the figure, write three concise statements identifying the category with the highest sample mean for each feature**

# %%
df.groupby('Track')['Average'].mean()
# Out:
# Track
# Communication       67.975
# Instrumentation     65.225
# Microelectronics    67.500
# Name: Average, dtype: float64

# %%
df.groupby('Gender')['Average'].mean()
# Out:
# Gender
# Female    66.616667
# Male      67.183333
# Name: Average, dtype: float64

# %%
df.groupby('Hometown')['Average'].mean()
# Out:
# Hometown
# Luzon       68.083333
# Mindanao    66.678571
# Visayas     65.750000
# Name: Average, dtype: float64

# %%
Highest_track = Track_table.loc[TrackTable['Average'].idxmax(), 'Track']
Highest_gender = Gender_table.loc[GenderTable['Average'].idxmax(), 'Gender']
Highest_hometown = Hometown_table.loc[HometownTable['Average'].idxmax(), 'Hometown']

print(f"{Highest_track} has the highest sample mean among the track categories.")
print(f"{Highest_gender} has the highest sample mean compare to other categories.")
print(f"{Highest_hometown} has the highest sample mean among the hometown categories.")
# Out:
# Communication has the highest sample mean among the track categories.
# Male has the highest sample mean compare to other categories.
# Luzon has the highest sample mean among the hometown categories.
